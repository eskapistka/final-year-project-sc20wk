# %% [markdown]
# Import data and select relevant columns

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from imblearn.over_sampling import SMOTE, ADASYN
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from scipy import stats
from sklearn.feature_selection import mutual_info_classif
from sklearn.feature_selection import RFE

# %%
# load adhd dataset
df = pd.read_csv('questionnaire_dataset.csv', sep=';')
feature_cols = ['gender', 'group'] + [f'tr{i}' for i in range(1, 44)] + [f'dass{i}' for i in range(1, 22)]
df = df[feature_cols].copy()
df.head()
# Out:
#    gender  group  tr1  tr2  tr3  tr4  tr5  tr6  tr7  tr8  ...  dass12  dass13  \
# 0       0      1    5    6    5    3    6    4    5    4  ...       3       3
# 1       1      1    5    3    5    5    6    4    5    5  ...       0       0
# 2       1      1    5    5    6    5    5    6    4    5  ...       3       2
# 3       1      1    6    6    6    6    5    6    6    6  ...       2       1
# 4       0      1    4    6    6    6    3    6    4    5  ...       3       3
#
#    dass14  dass15  dass16  dass17  dass18  dass19  dass20  dass21
# 0       3       1       1       2       2       1       1       2
# 1       0       0       0       0       2       0       0       0
# 2       3       2       2       1       3       2       2       2
# 3       1       0       0       1       1       1       1       3
# 4       2       2       2       3       1       0       0       1
#
# [5 rows x 66 columns]

# %% [markdown]
# Data preprocessing

# %%
# gender split of the dataset
print(f"Gender split before balancing the dataset: {len(df[df['gender'] == 0])} women to {len(df[df['gender'] == 1])} men.")
# Out:
# Gender split before balancing the dataset: 177 women to 43 men.

# %% [markdown]
# Balancing the dataset using oversampling techniques

# %%
# balance the dataset in regards to gender while keeping the same statistical properties
smote = SMOTE(k_neighbors=5, random_state=38)
adasyn = ADASYN(random_state=38)

X = df.copy().drop(columns=['gender'])
y = df['gender'].copy() # men = 1 / women = 0

# %% [markdown]
# Check whether SMOTE or ADASYN is better suited for oversampling the dataset

# %%
# split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=38)
# oversample the training set using SMOTE
X_resampled_smote, y_resampled_smote = smote.fit_resample(X_train, y_train)
# oversample the training set using ADASYN
X_resampled_adasyn, y_resampled_adasyn = adasyn.fit_resample(X_train, y_train)

classifiers = {
    "Random Forest": RandomForestClassifier(random_state=38),
    "Logistic Regression": LogisticRegression(random_state=38, max_iter=1000),
    "Support Vector Machine": SVC(random_state=38)
}

# smote
for name, classifier in classifiers.items():
    classifier.fit(X_resampled_smote, y_resampled_smote)
    y_pred = classifier.predict(X_test)
    print(f'SMOTE: Classification report for {name}.')
    print(classification_report(y_test, y_pred))

print('------------------------------------------------------------')

# adasyn
for name, classifier in classifiers.items():
    classifier.fit(X_resampled_adasyn, y_resampled_adasyn)
    y_pred = classifier.predict(X_test)
    print(f'ADASYN: Classification report for {name}.')
    print(classification_report(y_test, y_pred))
# Out:
# SMOTE: Classification report for Random Forest.
#               precision    recall  f1-score   support
#
#            0       0.89      0.88      0.88        56
#            1       0.36      0.40      0.38        10
#
#     accuracy                           0.80        66
#    macro avg       0.63      0.64      0.63        66
# weighted avg       0.81      0.80      0.81        66
#
# SMOTE: Classification report for Logistic Regression.
#               precision    recall  f1-score   support
#
#            0       0.93      0.77      0.84        56
#            1       0.35      0.70      0.47        10
#
#     accuracy                           0.76        66
#    macro avg       0.64      0.73      0.65        66
# weighted avg       0.85      0.76      0.79        66
#
# SMOTE: Classification report for Support Vector Machine.
#               precision    recall  f1-score   support
#
#            0       0.95      0.73      0.83        56
#            1       0.35      0.80      0.48        10
#
#     accuracy                           0.74        66
#    macro avg       0.65      0.77      0.66        66
# weighted avg       0.86      0.74      0.78        66
#
# ------------------------------------------------------------
# ADASYN: Classification report for Random Forest.
#               precision    recall  f1-score   support
#
#            0       0.90      0.95      0.92        56
#            1       0.57      0.40      0.47        10
#
#     accuracy                           0.86        66
#    macro avg       0.73      0.67      0.70        66
# weighted avg       0.85      0.86      0.85        66
#
# ADASYN: Classification report for Logistic Regression.
#               precision    recall  f1-score   support
#
#            0       0.95      0.75      0.84        56
#            1       0.36      0.80      0.50        10
#
#     accuracy                           0.76        66
#    macro avg       0.66      0.78      0.67        66
# weighted avg       0.87      0.76      0.79        66
#
# ADASYN: Classification report for Support Vector Machine.
#               precision    recall  f1-score   support
#
#            0       0.93      0.68      0.78        56
#            1       0.28      0.70      0.40        10
#
#     accuracy                           0.68        66
#    macro avg       0.60      0.69      0.59        66
# weighted avg       0.83      0.68      0.73        66

# %% [markdown]
# ADASYN generally shows better performance in terms of precision, recall, and F1-score compared to SMOTE across all classifiers (Random Forest, Logistic Regression, Support Vector Machine)
#
# It also achieves higher accuracy and better balance between precision and recall for both classes compared to SMOTE, indicating its effectiveness in handling the class imbalance

# %% [markdown]
# Apply ADASYN to the dataset

# %%
X_balanced, y_balanced = adasyn.fit_resample(X, y)
balanced_df = pd.concat([y_balanced, X_balanced], axis=1)
# gender split of the dataset
print(f"Gender split after balancing the dataset: {len(balanced_df[balanced_df['gender'] == 0])} women to {len(balanced_df[balanced_df['gender'] == 1])} men.")
balanced_df.describe()
# Out:
# Gender split after balancing the dataset: 177 women to 179 men.
#            gender       group         tr1         tr2         tr3         tr4  \
# count  356.000000  356.000000  356.000000  356.000000  356.000000  356.000000
# mean     0.502809    0.457865    3.542135    3.702247    4.794944    4.379213
# std      0.500696    0.498923    1.587245    1.536814    1.430090    1.470658
# min      0.000000    0.000000    1.000000    1.000000    1.000000    1.000000
# 25%      0.000000    0.000000    2.000000    2.000000    4.000000    3.000000
# 50%      1.000000    0.000000    4.000000    4.000000    5.000000    5.000000
# 75%      1.000000    1.000000    5.000000    5.000000    6.000000    5.000000
# max      1.000000    1.000000    6.000000    6.000000    6.000000    6.000000
#
#               tr5         tr6         tr7         tr8  ...      dass12  \
# count  356.000000  356.000000  356.000000  356.000000  ...  356.000000
# mean     3.870787    3.735955    3.292135    4.308989  ...    1.553371
# std      1.581634    1.652297    1.693083    1.622041  ...    1.020889
# min      1.000000    1.000000    1.000000    1.000000  ...    0.000000
# 25%      2.000000    2.000000    2.000000    3.000000  ...    1.000000
# 50%      4.000000    4.000000    4.000000    5.000000  ...    2.000000
# 75%      5.000000    5.000000    5.000000    6.000000  ...    2.000000
# max      6.000000    6.000000    6.000000    6.000000  ...    3.000000
#
#            dass13      dass14      dass15      dass16      dass17      dass18  \
# count  356.000000  356.000000  356.000000  356.000000  356.000000  356.000000
# mean     1.390449    1.294944    0.988764    0.761236    1.415730    1.595506
# std      0.879705    0.961265    0.987178    0.820005    1.027059    0.975406
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000    1.000000    0.000000    0.000000    1.000000    1.000000
# 50%      1.000000    1.000000    1.000000    1.000000    1.000000    2.000000
# 75%      2.000000    2.000000    2.000000    1.000000    2.000000    2.000000
# max      3.000000    3.000000    3.000000    3.000000    3.000000    3.000000
#
#            dass19      dass20      dass21
# count  356.000000  356.000000  356.000000
# mean     1.109551    1.033708    1.176966
# std      1.043730    1.025857    1.071857
# min      0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000
# 50%      1.000000    1.000000    1.000000
# 75%      2.000000    2.000000    2.000000
# max      3.000000    3.000000    3.000000
#
# [8 rows x 66 columns]

# %% [markdown]
# Train, test split of the balanced dataset

# %%
# split the dataset by gender 
balanced_df_women = balanced_df[balanced_df['gender'] == 0]
balanced_df_men = balanced_df[balanced_df['gender'] == 1]

# split it further into features and target variable
X_women = balanced_df_women.copy().drop(columns=['group', 'gender']).filter(regex='tr')
y_women = balanced_df_women['group'].copy() # adhd = 1 / no adhd = -1

X_men = balanced_df_men.copy().drop(columns=['group', 'gender']).filter(regex='tr')
y_men = balanced_df_men['group'].copy() # adhd = 1 / no adhd = -1

# %%
# stratified splitting to preserve a balanced class split according to diagnosis
# women
X_train_val_women, X_test_women, y_train_val_women, y_test_women = train_test_split(X_women, y_women, test_size=0.2, stratify=y_women, random_state=15) 
X_train_women, X_val_women, y_train_women, y_val_women = train_test_split(X_train_val_women, y_train_val_women, test_size=0.35, stratify=y_train_val_women, random_state=15) 

# men
X_train_val_men, X_test_men, y_train_val_men, y_test_men = train_test_split(X_men, y_men, test_size=0.2, stratify=y_men, random_state=15) 
X_train_men, X_val_men, y_train_men, y_val_men = train_test_split(X_train_val_men, y_train_val_men, test_size=0.35, stratify=y_train_val_men, random_state=15)

# %%
X_train_val = pd.concat([X_train_val_women, X_train_val_men])
y_train_val = pd.concat([y_train_val_women, y_train_val_men])

# %% [markdown]
# Feature selection

# %%
# number of features in the resulting questionnaire
feature_num = 25
# number of features to get through filter methods
filter_features_num = 30

# %%
# pTRAQ questions
# load the pTRAQ questions description CSV dataset file into a DataFrame
ptraq_questions = pd.read_csv('pTRAQ_questions.csv', sep=';')
# drop last row
ptraq_questions.drop(ptraq_questions.index[-1], inplace=True)

# %%
# add a column corresponding to the questionnaire dataset 
ptraq_questions = ptraq_questions.assign(question_code=[f'tr{i}' for i in range(1,43+1)])

# %%
dsm5_criteria = pd.read_csv('DSM5_ADHD_criteria.csv', sep=';')
# add columns with corresponding DSM-5 criteria and symptom category to pTRAQ questions
ptraq_questions = ptraq_questions.assign(dsm5_criteria=[c for c in dsm5_criteria['criteria_text']])
ptraq_questions = ptraq_questions.assign(symptom_category=[c for c in dsm5_criteria['category']])
#ptraq_questions.head()

# %% [markdown]
# Filter methods

# %% [markdown]
# Point Biserial Correlation

# %%
# get correlation of tr questions (1-6) to adhd diagnosis (0, 1)
# adhd group 1
# non-adhd group 0

# all data
question_cols = balanced_df.filter(regex='^tr\d+$').columns
correlations = []
p_values = []

for col in question_cols:
    corr, p_value = stats.pointbiserialr(balanced_df['group'], balanced_df[col])
    correlations.append(corr)
    p_values.append(p_value.round(3))

correlation_df = pd.DataFrame({
    'Question': question_cols,
    'Correlation': correlations,
    'P-value': p_values
})

corr_df = correlation_df.sort_values(by='Correlation', ascending=False)
corr_df = pd.merge(corr_df, ptraq_questions, left_on='Question', right_on='question_code', how='inner')
corr_df.drop(columns=['Question', 'Critère DSM-5','ID Critère','ID Projet', 'French Item (Validated)'])[:filter_features_num]
# Out:
#     Correlation  P-value                 English Item (Author's suggestion)  \
# 0      0.672552      0.0  I am often subject to forgetfulness in my dail...
# 1      0.632489      0.0  I find it hard to stay in place when the situa...
# 2      0.618190      0.0         My entourage finds me difficult to follow.
# 3      0.612023      0.0           I am easily distracted by my environment
# 4      0.581180      0.0  I often leave my seat unnecessarily during a m...
# 5      0.580423      0.0   I have trouble maintaining my attention at work.
# 6      0.574133      0.0  I tend to avoid tasks that require sustained m...
# 7      0.573525      0.0  I find it difficult to wait my turn in a conve...
# 8      0.570214      0.0               I have difficulty organizing my time
# 9      0.566096      0.0  My mind is often elsewhere, even when there is...
# 10     0.559445      0.0  The people around me think that I am a restles...
# 11     0.556191      0.0  It is difficult for me to organize tasks that ...
# 12     0.543057      0.0             I often lose things I need for my work
# 13     0.539844      0.0  I am easily distracted by what is going on aro...
# 14     0.538005      0.0  I have difficulty completing my tasks (work, h...
# 15     0.532421      0.0       I often leave my seat unnecessarily at work.
# 16     0.532254      0.0            I don't really pay attention to details
# 17     0.530548      0.0         I often wiggle my hands or feet on my seat
# 18     0.526756      0.0    I often make careless mistakes in my activities
# 19     0.507206      0.0            I often impose myself in conversations.
# 20     0.502189      0.0  I often give the answer to a question before i...
# 21     0.494207      0.0      I have difficulty complying with instructions
# 22     0.489990      0.0  It is difficult for me to wait my turn in a qu...
# 23     0.478140      0.0  My relatives blame me for not listening to the...
# 24     0.477781      0.0  I am often distracted by thoughts unrelated to...
# 25     0.476386      0.0           I often finish other people's sentences.
# 26     0.472799      0.0  It's hard for me to sit still for any length o...
# 27     0.472209      0.0     I have been accused of inaccuracies in my work
# 28     0.472107      0.0  I have difficulty staying focused during my ac...
# 29     0.468679      0.0  I often have trouble meeting my obligations (a...
#
#    question_code                                      dsm5_criteria  \
# 0           tr24  Is often forgetful in daily activities (e.g., ...
# 1           tr33  Often unable to play or engage in leisure acti...
# 2           tr34  Is often “on the go,” acting as if “driven by ...
# 3           tr21  Is often easily distracted by extraneous stimu...
# 4           tr28  Often leaves seat in situations when remaining...
# 5            tr4  Often has difficulty sustaining attention in t...
# 6           tr15  Often avoids, dislikes, or is reluctant to eng...
# 7           tr40  Often blurts out an answer before a question h...
# 8           tr12  Often has difficulty organizing tasks and acti...
# 9            tr8  Often does not seem to listen when spoken to d...
# 10          tr31  Often runs about or climbs in situations where...
# 11          tr14  Often has difficulty organizing tasks and acti...
# 12          tr19  Often loses things necessary for tasks or acti...
# 13          tr23  Is often easily distracted by extraneous stimu...
# 14          tr10  Often does not follow through on instructions ...
# 15          tr29  Often leaves seat in situations when remaining...
# 16           tr1  Often fails to give close attention to details...
# 17          tr26  Often fidgets with or taps hands or feet or sq...
# 18           tr3  Often fails to give close attention to details...
# 19          tr43  Often interrupts or intrudes on others (e.g., ...
# 20          tr38  Often blurts out an answer before a question h...
# 21           tr9  Often does not follow through on instructions ...
# 22          tr41  Often has difficulty waiting his or her turn (...
# 23           tr7  Often does not seem to listen when spoken to d...
# 24          tr22  Is often easily distracted by extraneous stimu...
# 25          tr39  Often blurts out an answer before a question h...
# 26          tr36  Is often “on the go,” acting as if “driven by ...
# 27           tr2  Often fails to give close attention to details...
# 28          tr11  Often does not follow through on instructions ...
# 29          tr25  Is often forgetful in daily activities (e.g., ...
#
#              symptom_category
# 0                 inattention
# 1   hyperactivity/impulsivity
# 2   hyperactivity/impulsivity
# 3                 inattention
# 4   hyperactivity/impulsivity
# 5                 inattention
# 6                 inattention
# 7   hyperactivity/impulsivity
# 8                 inattention
# 9                 inattention
# 10  hyperactivity/impulsivity
# 11                inattention
# 12                inattention
# 13                inattention
# 14                inattention
# 15  hyperactivity/impulsivity
# 16                inattention
# 17  hyperactivity/impulsivity
# 18                inattention
# 19  hyperactivity/impulsivity
# 20  hyperactivity/impulsivity
# 21                inattention
# 22  hyperactivity/impulsivity
# 23                inattention
# 24                inattention
# 25  hyperactivity/impulsivity
# 26  hyperactivity/impulsivity
# 27                inattention
# 28                inattention
# 29                inattention

# %% [markdown]
# Mutual Information

# %%
importances = []
features = []

mutual_info = mutual_info_classif(X_train_val, y_train_val)
for importance, feature in sorted(zip(mutual_info, X_train_val.columns), reverse=True):
    importances.append(importance)
    features.append(feature)

mutual_info_df = pd.DataFrame({
    'Feature': features,
    'Importance': importances
})

mutual_info_df[:filter_features_num]
# Out:
#    Feature  Importance
# 0     tr24    0.282138
# 1     tr34    0.239240
# 2     tr31    0.232254
# 3     tr12    0.218033
# 4      tr8    0.214652
# 5     tr21    0.211778
# 6     tr26    0.210912
# 7     tr14    0.207445
# 8     tr40    0.204635
# 9     tr28    0.202861
# 10    tr15    0.201946
# 11    tr33    0.201603
# 12     tr4    0.190075
# 13     tr3    0.185177
# 14    tr41    0.181330
# 15    tr19    0.167298
# 16    tr23    0.164554
# 17    tr16    0.160157
# 18    tr25    0.156617
# 19    tr39    0.149779
# 20     tr9    0.147059
# 21     tr1    0.146737
# 22    tr29    0.136537
# 23     tr2    0.131535
# 24    tr42    0.130891
# 25    tr10    0.129760
# 26    tr22    0.124980
# 27     tr7    0.124894
# 28    tr37    0.123498
# 29    tr27    0.117263

# %% [markdown]
# Wrapper methods

# %% [markdown]
# Resursive Feature Elimination

# %%
model = LogisticRegression(max_iter=500, random_state=15)

rfe = RFE(model, n_features_to_select=feature_num)

# use mutual information chosen features for RFE
mutual_info_features = mutual_info_df[:filter_features_num]
rfe.fit(X_train_val[mutual_info_features['Feature']], y_train_val)

rfe_selected_features = X_train_val[mutual_info_features['Feature']].columns[rfe.support_]
rfe_selected_features
# Out:
# Index(['tr24', 'tr34', 'tr12', 'tr8', 'tr21', 'tr26', 'tr14', 'tr40', 'tr15',
#        'tr33', 'tr4', 'tr3', 'tr41', 'tr19', 'tr23', 'tr25', 'tr9', 'tr1',
#        'tr2', 'tr42', 'tr10', 'tr22', 'tr7', 'tr37', 'tr27'],
#       dtype='object')

# %% [markdown]
# Correlation matrix for features chosen with RFE

# %%
cols = rfe_selected_features.tolist() + ['group']
corr = balanced_df[cols].corr()
plt.figure(figsize=(30, 30))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix for features selected using RFE')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix for features selected using RFE')

# %% [markdown]
# Check for multicollinearity - calculate the variance inflation factor (VIF)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant

X_train_selected = X_train_val.copy()[rfe_selected_features]

def calculate_vif(X):
    # X - dataframe with independent features
    X_constant = add_constant(X)
    # calculate vif
    vif_vals = pd.DataFrame()
    vif_vals['var'] = X_constant.columns
    vif_vals['vif'] = [variance_inflation_factor(X_constant.values, i) for i in range(X_constant.shape[1])]
    
    return vif_vals[vif_vals['var'] != 'const'].sort_values(by='vif', ascending=False)

vif_results = calculate_vif(X_train_selected)
# iterate until all VIF values are less than 5
while vif_results['vif'].max() > 5: 
    # find the column with the highest VIF
    max_vif_column = vif_results.loc[vif_results['vif'].idxmax(), 'var']
    print(f'dropping {max_vif_column}')
    # remove the column with the highest VIF
    X_train_selected = X_train_selected.drop(columns=[max_vif_column])
    # recalculate VIF
    vif_results = calculate_vif(X_train_selected)

vif_results.sort_values(by='vif', ascending=True)
# Out:
# dropping tr34
# dropping tr12
# dropping tr23
# dropping tr3
# dropping tr33
# dropping tr22
#      var       vif
# 6   tr40  2.532116
# 14   tr2  2.803655
# 8    tr4  2.830262
# 7   tr15  2.843980
# 15  tr42  3.169806
# 10  tr19  3.228231
# 5   tr14  3.276236
# 18  tr37  3.307817
# 11  tr25  3.354977
# 16  tr10  3.398507
# 3   tr21  3.455500
# 12   tr9  3.491837
# 13   tr1  3.521506
# 17   tr7  3.522247
# 19  tr27  3.581851
# 2    tr8  3.874742
# 9   tr41  3.941866
# 1   tr24  4.328569
# 4   tr26  4.910842

# %% [markdown]
# Resulting questionnaire

# %%
screening_features = rfe_selected_features

# %%
screening_questions = ptraq_questions.drop(columns=['ID Critère', 'ID Projet', 'French Item (Validated)'])

screening_questions = screening_questions[screening_questions['question_code'].isin(screening_features)]
screening_questions
# Out:
#    Critère DSM-5                 English Item (Author's suggestion)  \
# 0              A            I don't really pay attention to details
# 1              A     I have been accused of inaccuracies in my work
# 2              A    I often make careless mistakes in my activities
# 3              B   I have trouble maintaining my attention at work.
# 6              C  My relatives blame me for not listening to the...
# 7              C  My mind is often elsewhere, even when there is...
# 8              D      I have difficulty complying with instructions
# 9              D  I have difficulty completing my tasks (work, h...
# 11             E               I have difficulty organizing my time
# 13             E  It is difficult for me to organize tasks that ...
# 14             F  I tend to avoid tasks that require sustained m...
# 18             G             I often lose things I need for my work
# 20             H           I am easily distracted by my environment
# 21             H  I am often distracted by thoughts unrelated to...
# 22         H (C)  I am easily distracted by what is going on aro...
# 23             I  I am often subject to forgetfulness in my dail...
# 24             I  I often have trouble meeting my obligations (a...
# 25      a (c, d)         I often wiggle my hands or feet on my seat
# 26         a (d)                       I have trouble sitting still
# 32             d  I find it hard to stay in place when the situa...
# 33             e         My entourage finds me difficult to follow.
# 36             f                I tend to monopolize conversations.
# 39       g (h,f)  I find it difficult to wait my turn in a conve...
# 40             h  It is difficult for me to wait my turn in a qu...
# 41             i        I often interrupt others when they are busy
#
#    question_code                                      dsm5_criteria  \
# 0            tr1  Often fails to give close attention to details...
# 1            tr2  Often fails to give close attention to details...
# 2            tr3  Often fails to give close attention to details...
# 3            tr4  Often has difficulty sustaining attention in t...
# 6            tr7  Often does not seem to listen when spoken to d...
# 7            tr8  Often does not seem to listen when spoken to d...
# 8            tr9  Often does not follow through on instructions ...
# 9           tr10  Often does not follow through on instructions ...
# 11          tr12  Often has difficulty organizing tasks and acti...
# 13          tr14  Often has difficulty organizing tasks and acti...
# 14          tr15  Often avoids, dislikes, or is reluctant to eng...
# 18          tr19  Often loses things necessary for tasks or acti...
# 20          tr21  Is often easily distracted by extraneous stimu...
# 21          tr22  Is often easily distracted by extraneous stimu...
# 22          tr23  Is often easily distracted by extraneous stimu...
# 23          tr24  Is often forgetful in daily activities (e.g., ...
# 24          tr25  Is often forgetful in daily activities (e.g., ...
# 25          tr26  Often fidgets with or taps hands or feet or sq...
# 26          tr27  Often fidgets with or taps hands or feet or sq...
# 32          tr33  Often unable to play or engage in leisure acti...
# 33          tr34  Is often “on the go,” acting as if “driven by ...
# 36          tr37                           Often talks excessively.
# 39          tr40  Often blurts out an answer before a question h...
# 40          tr41  Often has difficulty waiting his or her turn (...
# 41          tr42  Often interrupts or intrudes on others (e.g., ...
#
#              symptom_category
# 0                 inattention
# 1                 inattention
# 2                 inattention
# 3                 inattention
# 6                 inattention
# 7                 inattention
# 8                 inattention
# 9                 inattention
# 11                inattention
# 13                inattention
# 14                inattention
# 18                inattention
# 20                inattention
# 21                inattention
# 22                inattention
# 23                inattention
# 24                inattention
# 25  hyperactivity/impulsivity
# 26  hyperactivity/impulsivity
# 32  hyperactivity/impulsivity
# 33  hyperactivity/impulsivity
# 36  hyperactivity/impulsivity
# 39  hyperactivity/impulsivity
# 40  hyperactivity/impulsivity
# 41  hyperactivity/impulsivity

# %%
# save the questionnaire into a csv format
file_name = f'{feature_num}_screening_questions.csv'
screening_questions.to_csv(file_name, index=False, sep=';')
